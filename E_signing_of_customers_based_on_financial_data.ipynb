# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('financial_data.csv')

# %%
# init dataset exploration
dataset.head()
# Out:
#    entry_id  age  pay_schedule  home_owner  income  months_employed  \
# 0   7629673   40     bi-weekly           1    3135                0
# 1   3560428   61        weekly           0    3180                0
# 2   6934997   23        weekly           0    1540                6
# 3   5682812   40     bi-weekly           0    5230                0
# 4   5335819   33  semi-monthly           0    3590                0
#
#    years_employed  current_address_year  personal_account_m  \
# 0               3                     3                   6
# 1               6                     3                   2
# 2               0                     0                   7
# 3               6                     1                   2
# 4               5                     2                   2
#
#    personal_account_y  ...  amount_requested  risk_score  risk_score_2  \
# 0                   2  ...               550       36200      0.737398
# ...

# %%
dataset.columns
# Out:
# Index(['entry_id', 'age', 'pay_schedule', 'home_owner', 'income',
#        'months_employed', 'years_employed', 'current_address_year',
#        'personal_account_m', 'personal_account_y', 'has_debt',
#        'amount_requested', 'risk_score', 'risk_score_2', 'risk_score_3',
#        'risk_score_4', 'risk_score_5', 'ext_quality_score',
#        'ext_quality_score_2', 'inquiries_last_month', 'e_signed'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17908 entries, 0 to 17907
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   entry_id              17908 non-null  int64
#  1   age                   17908 non-null  int64
#  2   pay_schedule          17908 non-null  object
#  3   home_owner            17908 non-null  int64
#  4   income                17908 non-null  int64
#  5   months_employed       17908 non-null  int64
#  6   years_employed        17908 non-null  int64
#  7   current_address_year  17908 non-null  int64
#  8   personal_account_m    17908 non-null  int64
#  9   personal_account_y    17908 non-null  int64
#  10  has_debt              17908 non-null  int64
#  11  amount_requested      17908 non-null  int64
#  12  risk_score            17908 non-null  int64
#  13  risk_score_2          17908 non-null  float64
#  14  risk_score_3          17908 non-null  float64
# ...

# %%
# summary
dataset.describe()
# Out:
#            entry_id           age    home_owner        income  \
# count  1.790800e+04  17908.000000  17908.000000  17908.000000
# mean   5.596978e+06     43.015412      0.425173   3657.214653
# std    2.562473e+06     11.873107      0.494383   1504.890063
# min    1.111398e+06     18.000000      0.000000    905.000000
# 25%    3.378999e+06     34.000000      0.000000   2580.000000
# 50%    5.608376e+06     42.000000      0.000000   3260.000000
# 75%    7.805624e+06     51.000000      1.000000   4670.000000
# max    9.999874e+06     96.000000      1.000000   9985.000000
#
#        months_employed  years_employed  current_address_year  \
# count     17908.000000    17908.000000          17908.000000
# mean          1.186006        3.526860              3.584711
# std           2.400897        2.259732              2.751937
# min           0.000000        0.000000              0.000000
# 25%           0.000000        2.000000              2.000000
# ...

# %%
# null values
dataset.isnull().values.any()
# Out:
# False

# %%
# figuring out categotical data
dataset.select_dtypes(include='object').columns
# Out:
# Index(['pay_schedule'], dtype='object')

# %%
dataset['pay_schedule'].unique()
# Out:
# array(['bi-weekly', 'weekly', 'semi-monthly', 'monthly'], dtype=object)

# %%
dataset.shape
# Out:
# (17908, 21)

# %%
dataset = pd.get_dummies(data=dataset,drop_first=True)

# %%
dataset.shape
# Out:
# (17908, 23)

# %%
# making a countplot of what we are supposed to predict
sns.countplot(dataset['e_signed'])

# %%
(dataset.e_signed == 1).sum()
# Out:
# 9639

# %%
(dataset.e_signed == 0).sum()
# Out:
# 8269

# %%
# restructuring data so that the columns with year and month just 
# show up as month
dataset.head()
# Out:
#    entry_id  age  home_owner  income  months_employed  years_employed  \
# 0   7629673   40           1    3135                0               3
# 1   3560428   61           0    3180                0               6
# 2   6934997   23           0    1540                6               0
# 3   5682812   40           0    5230                0               6
# 4   5335819   33           0    3590                0               5
#
#    current_address_year  personal_account_m  personal_account_y  has_debt  \
# 0                     3                   6                   2         1
# 1                     3                   2                   7         1
# 2                     0                   7                   1         1
# 3                     1                   2                   7         1
# 4                     2                   2                   8         1
#
#    ...  risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# ...

# %%
dataset['months_employed'] = (dataset.months_employed + dataset.years_employed*12)

# %%
dataset.head()
# Out:
#    entry_id  age  home_owner  income  months_employed  years_employed  \
# 0   7629673   40           1    3135               36               3
# 1   3560428   61           0    3180               72               6
# 2   6934997   23           0    1540                6               0
# 3   5682812   40           0    5230               72               6
# 4   5335819   33           0    3590               60               5
#
#    current_address_year  personal_account_m  personal_account_y  has_debt  \
# 0                     3                   6                   2         1
# 1                     3                   2                   7         1
# 2                     0                   7                   1         1
# 3                     1                   2                   7         1
# 4                     2                   2                   8         1
#
#    ...  risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# ...

# %%
dataset = dataset.drop(columns=['years_employed'])

# %%
dataset['personal_account_m'] = (dataset.personal_account_m + dataset.personal_account_y*12)

# %%
dataset = dataset.drop(columns=['personal_account_y'])

# %%
dataset
# Out:
#        entry_id  age  home_owner  income  months_employed  \
# 0       7629673   40           1    3135               36
# 1       3560428   61           0    3180               72
# 2       6934997   23           0    1540                6
# 3       5682812   40           0    5230               72
# 4       5335819   33           0    3590               60
# ...         ...  ...         ...     ...              ...
# 17903   9949728   31           0    3245               60
# 17904   9442442   46           0    6525               24
# 17905   9857590   46           0    2685               60
# 17906   8708471   42           0    2515               36
# 17907   1498559   29           1    2665               48
#
#        current_address_year  personal_account_m  has_debt  amount_requested  \
# 0                         3                  30         1               550
# 1                         3                  86         1               600
# ...

# %%
# Correlation with e_signed
dataset_1 = dataset.drop(columns=['entry_id','e_signed'])
dataset_1.corrwith(dataset['e_signed']).plot.bar(
    figsize=(20,10), title='Correlated with e_signed'
)

# %%
plt.figure(figsize=(20,10))
ax = sns.heatmap(dataset.corr())

# %%
dataset.head()
# Out:
#    entry_id  age  home_owner  income  months_employed  current_address_year  \
# 0   7629673   40           1    3135               36                     3
# 1   3560428   61           0    3180               72                     3
# 2   6934997   23           0    1540                6                     0
# 3   5682812   40           0    5230               72                     1
# 4   5335819   33           0    3590               60                     2
#
#    personal_account_m  has_debt  amount_requested  risk_score  ...  \
# 0                  30         1               550       36200  ...
# 1                  86         1               600       30150  ...
# 2                  19         1               450       34550  ...
# 3                  86         1               700       42150  ...
# 4                  98         1              1100       53850  ...
#
#    risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# ...

# %%
x = dataset.drop(columns=['entry_id','e_signed'])
y = dataset['e_signed']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25, random_state = 0)

# %%
# feature scaling or standardization over a range of values
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
# Logistic Regression Model
from sklearn.linear_model import LogisticRegression
classifr_lr = LogisticRegression(random_state=0)
classifr_lr.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = classifr_lr.predict(x_test)
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.5642171096716552

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 819, 1261],
#        [ 690, 1707]], dtype=int64)

# %%
# Support Vector Model (SVM)
from sklearn.svm import SVC
classifr_svc = SVC(random_state=0)
classifr_svc.fit(x_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %%
y_pred = classifr_svc.predict(x_test)
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.5928076837167746

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 986, 1094],
#        [ 729, 1668]], dtype=int64)

# %%
# RandomForest Model
from sklearn.ensemble import RandomForestClassifier
classifr_rf = RandomForestClassifier(random_state = 0)
classifr_rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
y_pred = classifr_rf.predict(x_test)
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.6149207058297967

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1146,  934],
#        [ 790, 1607]], dtype=int64)

# %%
# Applying Randomized Search to find the best parameters
# using the randomforest classifier as that has the highest acc score
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters = {
    'bootstrap': [True, False],
    'max_depth':[3, 4, 5, 6, 8, 10, 12, 15],
    'max_features': ['auto', 'sqrt'],
    'min_samples_leaf': [1, 2, 4],
    'min_samples_split': [2, 5, 10],
    'n_estimators':[100, 200, 500]
}

# %%
random_cv = RandomizedSearchCV(estimator=classifr_rf, param_distributions=parameters, 
                              scoring='roc_auc', n_jobs=-1, cv = 5, verbose=3)

# %%
random_cv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   53.8s finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     max_samples=None,
#                                                     min_impurity_decrease=0.0,
# ...

# %%
random_cv.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=12, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
random_cv.best_params_
# Out:
# {'n_estimators': 500,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 12,
#  'bootstrap': False}

# %%
random_cv.best_score_
# Out:
# 0.6899339947973951

# %%
# Final model using Random Forest Regression
from sklearn.ensemble import RandomForestClassifier
classifr = RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=12, max_features='sqrt',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=2, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, n_estimators=500,
                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
                       warm_start=False)

# %%
classifr.fit(x_train, y_train)
y_pred = classifr.predict(x_test)
from sklearn.metrics import confusion_matrix, accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.6348000893455439

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1152,  928],
#        [ 707, 1690]], dtype=int64)

# %%
# prediction a value
dataset.head()
# Out:
#    entry_id  age  home_owner  income  months_employed  current_address_year  \
# 0   7629673   40           1    3135               36                     3
# 1   3560428   61           0    3180               72                     3
# 2   6934997   23           0    1540                6                     0
# 3   5682812   40           0    5230               72                     1
# 4   5335819   33           0    3590               60                     2
#
#    personal_account_m  has_debt  amount_requested  risk_score  ...  \
# 0                  30         1               550       36200  ...
# 1                  86         1               600       30150  ...
# 2                  19         1               450       34550  ...
# 3                  86         1               700       42150  ...
# 4                  98         1              1100       53850  ...
#
#    risk_score_3  risk_score_4  risk_score_5  ext_quality_score  \
# ...

# %%
single_obs = [[45, 1, 2500,	3,	1,	600,	37000,	0.7373, 0.9035, 0.4877, 0.515977, 0.580918, 0.380918, 10, 0, 0, 0, 36, 30]]

# %%
classifr.predict(sc.transform(single_obs))
# Out:
# array([0], dtype=int64)

# %%
# works
